# %%
pip install mediapy
# Out:
# Requirement already satisfied: mediapy in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (1.2.4)
# Requirement already satisfied: ipython in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from mediapy) (9.7.0)
# Requirement already satisfied: matplotlib in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from mediapy) (3.10.6)
# Requirement already satisfied: numpy in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from mediapy) (2.2.6)
# Requirement already satisfied: Pillow in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from mediapy) (11.3.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from ipython->mediapy) (5.14.3)
# Requirement already satisfied: wcwidth in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from jedi>=0.18.1->ipython->mediapy) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from pexpect>4.3->ipython->mediapy) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->mediapy) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->mediapy) (3.0.1)
# Requirement already satisfied: pure-eval in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->mediapy) (0.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from matplotlib->mediapy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/umberto-francesco-carolini/Downloads/self_balancing_robot_with_DRL-main/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mediapy) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import time
import mujoco
import mujoco.viewer
# from mujoco import mjx
import mediapy as media
import matplotlib.pyplot as plt
from IPython.display import display, Video

# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)

# %%
model = mujoco.MjModel.from_xml_path("../models/scene.xml")
data = mujoco.MjData(model)

duration = 10  # (seconds)
framerate = 30  # (Hz)
width, height = 720, 480  # Desired resolution

# Apply random inputs to the actuators
mujoco.mj_resetData(model, data)
# data.ctrl[:] = np.random.uniform(-1, 1, data.ctrl.shape)
data.ctrl[:] = np.array([0.0, 0.0])

# enable joint visualization option:
scene_option = mujoco.MjvOption()
scene_option.flags[mujoco.mjtVisFlag.mjVIS_JOINT] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = False
scene_option.geomgroup[:] = 1  # Enable visibility for all groups

count = 0

# Simulate and display video.
frames = []
joint_angles = []
with mujoco.Renderer(model, width=width, height=height) as renderer:
  while data.time < duration:
    mujoco.mj_step(model, data)
    joint_angles.append(data.sensordata.copy()) # Record joint angles
    if len(frames) < data.time * framerate:
      renderer.update_scene(data, scene_option=scene_option)
      pixels = renderer.render()
      frames.append(pixels)
    
    if data.time > 4:
      data.ctrl[:] = np.array([1, 1])

# %%
# Plot joint angles with joint names in legend
joint_angles = np.array(joint_angles)[1990:2300, :]
time = np.linspace(0, joint_angles.shape[0] * 0.002, joint_angles.shape[0])

plt.figure(figsize=(12, 6))
sensor_names = [model.sensor(i).name for i in range(2)]
for i in range(2):
    plt.plot(time, joint_angles[:, i], label=sensor_names[i])
plt.xlabel('Time (s)')
plt.ylabel('Joint Angle (rad)')
plt.title('Joint Angles Over Time')
plt.legend(sensor_names)
plt.grid(True)
plt.show()
